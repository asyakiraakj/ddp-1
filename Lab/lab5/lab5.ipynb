# %%
def format_rupiah(angka): 
    # 1 125 123 -> 1.215.123
    # 1 123 456
    # 12 123 456 
    # 123 123 456
    # TODO: kembalikan string dalam format "RpX.XXX,-"
    digits = ""
    while angka != 0:
        last_three = angka % 1000
        digits = digits + "." + str(last_three)
        angka // 1000
        if len(str(angka)) == 1 or len(str(angka)) == 2 or len(str(angka)) == 3:
            digits = angka + "." + digits

    angka_rupiah = "Rp" + digits + ",-"

    return angka_rupiah
print("hello")
print(format_rupiah(1125123))
# Out:
# hello
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 19
#      17     return angka_rupiah
#      18 print("hello")
# ---> 19 print(format_rupiah(1125123))
#
# Cell In[18], line 12, in format_rupiah(angka)
#      10     digits = digits + "." + str(last_three)
#      11     angka // 1000
# ---> 12     if len(str(angka)) == 1 or len(str(angka)) == 2 or len(str(angka)) == 3:
#      13         digits = angka + "." + digits
#      15 angka_rupiah = "Rp" + digits + ",-"
#
# KeyboardInterrupt:
