# %%
d = {}

d["city"] = "Depok"

print(d)
# Out:
# {'city': 'Depok'}

# %%
keluarga = {}  

keluarga = {
    "Andi": [("Budi", 1980), ("Cici", 1985)],
    "Budi": [("Deni", 2005)],
    "Cici": [],
    "Deni": []
}

root = None 

def print_tree(nama: str, level: int):
    """
    Cetak pohon keluarga mulai dari 'nama' sebagai akar lokal.
    Aturan cetak:
    - Jika level == 0, tampilkan: "<nama> (root)"
    - Jika level > 0:
        - Jika tahun tersedia: "  " * level + "<nama> (<tahun>)"
        - Jika tidak:          "  " * level + "<nama>"
    - Lalu, untuk setiap anak dari 'nama', panggil print_tree(anak, level+1)

    Lakukan:
    - Cetak baris untuk node saat ini sesuai aturan di atas.
    - Ambil daftar anak dari 'keluarga[nama]' jika ada.
    - Rekursi memanggil dirinya untuk setiap anak dengan level+1.
    """
    # TODO: implementasi print_tree
    if level == 0:
        print(f"{nama} (root)")
        print_tree(nama, level+1)
    elif level > 0:
        print(f"{" "*level} {nama}")

    print_tree(keluarga[nama], level+1)

    pass  # placeholder

nama_root = input("Masukkan nama akar keluarga: ").strip()
#TODO: validasi bahwa nama_root ada di data
if nama_root in keluarga:
    print_tree(nama_root, 0)
# Out:
# Andi (root)
#   Andi
#    [('Budi', 1980), ('Cici', 1985)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 41
#      39 #TODO: validasi bahwa nama_root ada di data
#      40 if nama_root in keluarga:
# ---> 41     print_tree(nama_root, 0)
#
# Cell In[10], line 30, in print_tree(nama, level)
#      28 if level == 0:
#      29     print(f"{nama} (root)")
# ---> 30     print_tree(nama, level+1)
#      31 elif level > 0:
#      32     print(f"{" "*level} {nama}")
#
# Cell In[10], line 34, in print_tree(nama, level)
#      31 elif level > 0:
#      32     print(f"{" "*level} {nama}")
# ---> 34 print_tree(keluarga[nama], (level+1))
#      36 pass
#
# Cell In[10], line 34, in print_tree(nama, level)
#      31 elif level > 0:
#      32     print(f"{" "*level} {nama}")
# ---> 34 print_tree(keluarga[nama], (level+1))
#      36 pass
#
# TypeError: unhashable type: 'list'

# %%
print(keluarga['Andi'])
# Out:
# ('Budi', 1980)

# %%
print()
LAB = (((95 + 100 + 55*8)/10) *0.1)
UTS = 81*0.3
KUIS = 85*0.2
UAS = 85*0.4

print(LAB + UTS + KUIS + UAS)
# Out:
# 81.65
