# %% [markdown]
# Buatlah program yang menerima input nama dari 2 buah file teks yang berisi kumpulan kata-kata. Program kemudian membaca isi dari 2 file tersebut dan menampilkan nilai yang menandakan seberapa mirip isi dari dua file tersebut.
# Kemiripan dihitung dengan **Jaccard Similarity**

# %%
file_1 = "input_2.txt" #input("File 1:")
file_2 = "input_3.txt" #input("File 2: ")
with open (file_1, "r") as f,\
     open(file_2, "r") as f2:

    set_1 = set()
    for words in f.read().split():
        words.strip()
        set_1.add(words)

    set_2 = set()
    for words2 in f2.read().split():
        words2.strip()
        set_2.add(words2)

    union_a_b = len(set_1.union(set_2))
    intersect_a_b = len(set_1.intersection(set_2))

    f.seek(0)
    f2.seek(0)
    intersect = 

    kemiripan = union_a_b / total_element
    print(kemiripan)
# Out:
# 0.4444444444444444
